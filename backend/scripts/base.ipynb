# %%
#Create db
import sqlite3
def create_table():
    conn = sqlite3.connect('event_data.db')
    c = conn.cursor()
    c.execute('''CREATE TABLE IF NOT EXISTS api_data
                 (id TEXT, host TEXT, method TEXT, payload TEXT, address TEXT, response TEXT)''')
    conn.commit()
    conn.close()

# %%
import requests
import sqlite3
import json
import hashlib

def get_hash(input_text):
    return hashlib.sha256(input_text.encode()).hexdigest()

def insert_db_call(id, host, method, payload, address, response_text):
    conn = sqlite3.connect('event_data.db')
    c = conn.cursor()
    c.execute("INSERT INTO api_data VALUES (?, ?, ?, ?, ?, ?)",
              (id, host, method, payload, address, response_text))
    conn.commit()
    conn.close()

def process_event(event):
    # Unpacking    event
    id = event['id']
    host = event['host']
    method = event['method']
    payload = event['payload']
    address = event['address']

    # API call
    try:
        if method.upper() == 'POST':
            response = requests.post(host, json=payload)
        elif method.upper() == 'GET':
            response = requests.get(host, params=payload)
        else:
            return "Method not supported"

        response = get_hash(response.text)
    except Exception as e:
        response = get_hash(str(e))

    insert_db_call(id, host, method, json.dumps(payload), address, response)


    #Starks call contract insert

# %%
# !pip install starknet-py
# Out:
# ^C
# Collecting starknet-py
#   Downloading starknet_py-0.22.0.tar.gz (81 kB)
#      ---------------------------------------- 81.3/81.3 kB 1.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting lark<2.0.0,>=1.1.5
#   Downloading lark-1.1.9-py3-none-any.whl (111 kB)
#      -------------------------------------- 111.7/111.7 kB 3.3 MB/s eta 0:00:00
# Collecting aiohttp<4.0.0,>=3.8.4
#   Downloading aiohttp-3.9.5-cp310-cp310-win_amd64.whl (370 kB)
#      -------------------------------------- 370.7/370.7 kB 5.7 MB/s eta 0:00:00
# Collecting pycryptodome<4.0,>=3.17
#   Downloading pycryptodome-3.20.0-cp35-abi3-win_amd64.whl (1.8 MB)
#      ---------------------------------------- 1.8/1.8 MB 9.3 MB/s eta 0:00:00
# Collecting marshmallow-oneofschema==3.0.1
#   Downloading marshmallow_oneofschema-3.0.1-py2.py3-none-any.whl (5.8 kB)
# Collecting typing-extensions<5.0.0,>=4.3.0
#   Downloading typing_extensions-4.12.0-py3-none-any.whl (37 kB)
# Collecting marshmallow-dataclass<8.7.0
#   Downloading marshmallow_dataclass-8.6.1-py3-none-any.whl (18 kB)
# Collecting poseidon-py==0.1.4
#   Downloading poseidon_py-0.1.4-cp310-cp310-win_amd64.whl (39 kB)
# Collecting crypto-cpp-py==1.4.4
#   Downloading crypto_cpp_py-1.4.4-cp310-cp310-win_amd64.whl (175 kB)
#      -------------------------------------- 175.8/175.8 kB 5.3 MB/s eta 0:00:00
# Collecting marshmallow<4.0.0,>=3.15.0
#   Downloading marshmallow-3.21.2-py3-none-any.whl (49 kB)
#      ---------------------------------------- 49.3/49.3 kB 2.4 MB/s eta 0:00:00
# Collecting asgiref<4.0.0,>=3.4.1
#   Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting sympy==1.11.1
#   Using cached sympy-1.11.1-py3-none-any.whl (6.5 MB)
# Collecting ecdsa==0.18.0
#   Downloading ecdsa-0.18.0-py2.py3-none-any.whl (142 kB)
#      -------------------------------------- 142.9/142.9 kB 8.3 MB/s eta 0:00:00
# Collecting pywin32==306
#   Downloading pywin32-306-cp310-cp310-win_amd64.whl (9.2 MB)
#      ---------------------------------------- 9.2/9.2 MB 8.4 MB/s eta 0:00:00
# Collecting six>=1.9.0
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      -------------------------------------- 536.2/536.2 kB 8.3 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.5-cp310-cp310-win_amd64.whl (28 kB)
# Collecting attrs>=17.3.0
#   Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.4.1-cp310-cp310-win_amd64.whl (50 kB)
# Collecting async-timeout<5.0,>=4.0
#   Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting yarl<2.0,>=1.0
#   Using cached yarl-1.9.4-cp310-cp310-win_amd64.whl (76 kB)
# Collecting packaging>=17.0
#   Using cached packaging-24.0-py3-none-any.whl (53 kB)
# Collecting typing-inspect<1.0,>=0.8.0
#   Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting mypy-extensions>=0.3.0
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting idna>=2.0
#   Downloading idna-3.7-py3-none-any.whl (66 kB)
#      ---------------------------------------- 66.8/66.8 kB 3.5 MB/s eta 0:00:00
# Building wheels for collected packages: starknet-py
#   Building wheel for starknet-py (pyproject.toml): started
#   Building wheel for starknet-py (pyproject.toml): finished with status 'done'
#   Created wheel for starknet-py: filename=starknet_py-0.22.0-py3-none-any.whl size=124812 sha256=e744f0a410592aadf7d99720e729e9c714f884e23e96df1866b192e144358dec
#   Stored in directory: c:\users\noel\appdata\local\pip\cache\wheels\22\7a\9d\1d29839d8778f31d3d9dda8d41dd35d376ae4e8392c1624466
# Successfully built starknet-py
# Installing collected packages: pywin32, mpmath, typing-extensions, sympy, six, pycryptodome, poseidon-py, packaging, mypy-extensions, multidict, lark, idna, frozenlist, attrs, async-timeout, yarl, typing-inspect, marshmallow, ecdsa, asgiref, aiosignal, marshmallow-oneofschema, marshmallow-dataclass, crypto-cpp-py, aiohttp, starknet-py
# Successfully installed aiohttp-3.9.5 aiosignal-1.3.1 asgiref-3.8.1 async-timeout-4.0.3 attrs-23.2.0 crypto-cpp-py-1.4.4 ecdsa-0.18.0 frozenlist-1.4.1 idna-3.7 lark-1.1.9 marshmallow-3.21.2 marshmallow-dataclass-8.6.1 marshmallow-oneofschema-3.0.1 mpmath-1.3.0 multidict-6.0.5 mypy-extensions-1.0.0 packaging-24.0 poseidon-py-0.1.4 pycryptodome-3.20.0 pywin32-306 six-1.16.0 starknet-py-0.22.0 sympy-1.11.1 typing-extensions-4.12.0 typing-inspect-0.9.0 yarl-1.9.4
#   WARNING: The script isympy.exe is installed in 'C:\Users\Noel\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: C:\Users\Noel\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
